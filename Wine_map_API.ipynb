# %%
 # Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
from config import api_key

# %%
# Import wines_updated4.csv as DataFrame
wine_data_pd= pd.read_csv("wines_data_updated.csv")
wine_data_df = wine_data_pd.head(200)
wine_data_df
# Out:
#      Unnamed: 0                                              Title   Country  \
# 0             0  L'Arboc NV 1919 Brut SelecciÃƒÂ³ Sparkling (Cava)     Spain
# 1             1         Guidi 1929 2015 Vernaccia di San Gimignano     Italy
# 2             2  Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...     Italy
# 3             3  Adega Viuva Gomes 1934 Reserva Velho Red (Cola...  Portugal
# 4             4  Gérard Bertrand 1945 Legend Vintage Red (Rives...    France
# ..          ...                                                ...       ...
# 195         195                      Piccini 1998 Chianti Classico     Italy
# 196         196                  Talus 1998 Zinfandel (California)        US
# 197         197  Argyle 1998 Spirit House Pinot Noir (Willamett...        US
# 198         198  Rosenblum 1998 Rockpile Road Zinfandel (Dry Cr...        US
# 199         199     Savannah-Chanelle 1998 Zinfandel (Paso Robles)        US
#
#      Points     Price              Province          Variety  \
# 0        88   $13.00              Catalonia  Sparkling Blend
# 1        87   $14.00                Tuscany        Vernaccia
# 2        84   $15.00          Central Italy       Sangiovese
# 3        93  $495.00                Colares          Ramisco
# 4        95  $350.00   Languedoc-Roussillon        Red Blend
# ..      ...       ...                   ...              ...
# 195      84   $11.00                Tuscany       Sangiovese
# 196      85    $8.00             California        Zinfandel
# 197      88   $50.00                 Oregon       Pinot Noir
# 198      90   $19.00             California        Zinfandel
# 199      87   $22.00             California        Zinfandel
#
#                       Winery
# 0                    L'Arboc
# 1                 Guidi 1929
# 2    Poderi dal Nespoli 1929
# 3          Adega Viuva Gomes
# 4            Gerard Bertrand
# ..                       ...
# 195                  Piccini
# 196                    Talus
# 197                   Argyle
# 198                Rosenblum
# 199        Savannah-Chanelle
#
# [200 rows x 8 columns]

# %%
# Add "Lat" and "Lng" columns to the Dataframe
 
wine_data_df["Lat"] = ""
wine_data_df["Lng"] = ""
wine_data_df.head(10)
# Out:
# C:\Users\mokae\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\mokae\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Unnamed: 0                                              Title   Country  \
# 0           0  L'Arboc NV 1919 Brut SelecciÃƒÂ³ Sparkling (Cava)     Spain
# 1           1         Guidi 1929 2015 Vernaccia di San Gimignano     Italy
# 2           2  Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...     Italy
# 3           3  Adega Viuva Gomes 1934 Reserva Velho Red (Cola...  Portugal
# 4           4  Gérard Bertrand 1945 Legend Vintage Red (Rives...    France
# 5           5               Burmester 1952 Colheita Tawny (Port)  Portugal
# 6           6                 Messias 1963 Colheita Tawny (Port)  Portugal
# 7           7                  Barros 1974 Colheita Tawny (Port)  Portugal
# 8           8                   Kopke 1978 Colheita Tawny (Port)  Portugal
# 9           9            Adega de Favaios 1980 Moscatel do Douro  Portugal
#
#    Points     Price              Province          Variety  \
# 0      88   $13.00              Catalonia  Sparkling Blend
# 1      87   $14.00                Tuscany        Vernaccia
# 2      84   $15.00          Central Italy       Sangiovese
# 3      93  $495.00                Colares          Ramisco
# 4      95  $350.00   Languedoc-Roussillon        Red Blend
# 5      96  $415.00                   Port             Port
# 6      96  $400.00                   Port             Port
# 7      93  $175.00                   Port             Port
# 8      94  $100.00                   Port             Port
# 9      93  $137.00      Moscatel do Douro         Moscatel
#
#                     Winery Lat Lng
# 0                  L'Arboc
# 1               Guidi 1929
# 2  Poderi dal Nespoli 1929
# 3        Adega Viuva Gomes
# 4          Gerard Bertrand
# 5                Burmester
# 6                  Messias
# 7                   Barros
# 8                    Kopke
# 9         Adega de Favaios

# %%
#Use Google API to find lat and lng coordinates, and add to the dataframe

target_url = "https://maps.googleapis.com/maps/api/place/textsearch/json"

for index, row in wine_data_df.iterrows():
    try:
        params = {
        "query": row["Winery"],
        "key": api_key}
        response = requests.get(target_url, params)
        
        winery_lat_lng=response.json()
        
        wine_data_df.loc[index, "Lat"] = winery_lat_lng["results"][0]["geometry"]["location"]["lat"]
        wine_data_df.loc[index, "Lng"] = winery_lat_lng["results"][0]["geometry"]["location"]["lng"]
        
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.") 
print("---------------------------------------\nData Retrieval Complete\n---------------------------------------")
# Out:
# C:\Users\mokae\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# Missing field/result... skipping.
# ---------------------------------------
# Data Retrieval Complete
# ---------------------------------------

# %%
wine_data_df
# Out:
#      Unnamed: 0                                              Title   Country  \
# 0             0  L'Arboc NV 1919 Brut SelecciÃƒÂ³ Sparkling (Cava)     Spain
# 1             1         Guidi 1929 2015 Vernaccia di San Gimignano     Italy
# 2             2  Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...     Italy
# 3             3  Adega Viuva Gomes 1934 Reserva Velho Red (Cola...  Portugal
# 4             4  Gérard Bertrand 1945 Legend Vintage Red (Rives...    France
# ..          ...                                                ...       ...
# 195         195                      Piccini 1998 Chianti Classico     Italy
# 196         196                  Talus 1998 Zinfandel (California)        US
# 197         197  Argyle 1998 Spirit House Pinot Noir (Willamett...        US
# 198         198  Rosenblum 1998 Rockpile Road Zinfandel (Dry Cr...        US
# 199         199     Savannah-Chanelle 1998 Zinfandel (Paso Robles)        US
#
#      Points     Price              Province          Variety  \
# 0        88   $13.00              Catalonia  Sparkling Blend
# 1        87   $14.00                Tuscany        Vernaccia
# 2        84   $15.00          Central Italy       Sangiovese
# 3        93  $495.00                Colares          Ramisco
# 4        95  $350.00   Languedoc-Roussillon        Red Blend
# ..      ...       ...                   ...              ...
# 195      84   $11.00                Tuscany       Sangiovese
# 196      85    $8.00             California        Zinfandel
# 197      88   $50.00                 Oregon       Pinot Noir
# 198      90   $19.00             California        Zinfandel
# 199      87   $22.00             California        Zinfandel
#
#                       Winery      Lat      Lng
# 0                    L'Arboc   41.266  1.60203
# 1                 Guidi 1929  43.4711  11.1216
# 2    Poderi dal Nespoli 1929  44.0246  11.9818
# 3          Adega Viuva Gomes  38.7956  -9.4704
# 4            Gerard Bertrand  37.9848 -122.313
# ..                       ...      ...      ...
# 195                  Piccini  25.4431  -100.95
# 196                    Talus  37.7937 -122.268
# 197                   Argyle  37.9808 -122.297
# 198                Rosenblum  37.7953 -122.279
# 199        Savannah-Chanelle  37.2477 -122.079
#
# [200 rows x 10 columns]

# %%
wine_data_df.to_csv("wine_lat_lng1.csv", encoding="utf-8", index=True)

# %% [markdown]
#  # Top Ten

# %%
wine_data_pd
# Out:
#        Unnamed: 0                                              Title  \
# 0               0  L'Arboc NV 1919 Brut SelecciÃƒÂ³ Sparkling (Cava)
# 1               1         Guidi 1929 2015 Vernaccia di San Gimignano
# 2               2  Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...
# 3               3  Adega Viuva Gomes 1934 Reserva Velho Red (Cola...
# 4               4  Gérard Bertrand 1945 Legend Vintage Red (Rives...
# ...           ...                                                ...
# 24992       24992  Familie Zull 2016 Lust & Laune RosÃƒÂ© (Nieder...
# 24993       24993  JÃƒÂ¤ger 2016 Vorder Seiber Federspiel GrÃƒÂ¼n...
# 24994       24994             Zonin NV CuvÃƒÂ¨e 1821 Brut (Prosecco)
# 24995       24995  Osborne NV Pedro Ximenez 1827 Sweet Sherry She...
# 24996       24996  CodornÃƒÂ­u NV Reserva CuvÃƒÂ©e Barcelona 1872...
#
#         Country  Points     Price              Province              Variety  \
# 0         Spain      88   $13.00              Catalonia      Sparkling Blend
# 1         Italy      87   $14.00                Tuscany            Vernaccia
# 2         Italy      84   $15.00          Central Italy           Sangiovese
# 3      Portugal      93  $495.00                Colares              Ramisco
# 4        France      95  $350.00   Languedoc-Roussillon            Red Blend
# ...         ...     ...       ...                   ...                  ...
# 24992   Austria      88   $15.00    NiederÃƒÂ¶sterreich              RosÃƒÂ©
# 24993   Austria      90   $25.00                 Wachau  GrÃƒÂ¼ner Veltliner
# 24994     Italy      86   $15.00                 Veneto                Glera
# 24995     Spain      94   $14.00              Andalucia               Sherry
# 24996     Spain      85       NaN             Catalonia      Sparkling Blend
#
#                         Winery
# 0                      L'Arboc
# 1                   Guidi 1929
# 2      Poderi dal Nespoli 1929
# 3            Adega Viuva Gomes
# 4              Gerard Bertrand
# ...                        ...
# 24992             Familie Zull
# 24993                 JÃƒÂ¤ger
# 24994                    Zonin
# 24995                  Osborne
# 24996              CodornÃƒÂ­u
#
# [24997 rows x 8 columns]

# %%
unique = wine_data_pd["Variety"].unique()
len(unique)
unique
# Out:
# array(['Sparkling Blend', 'Vernaccia', 'Sangiovese', 'Ramisco',
#        'Red Blend', 'Port', 'Moscatel', 'Cabernet Sauvignon',
#        'Champagne Blend', 'Riesling', 'White Blend', 'Chardonnay',
#        'Tempranillo Blend', 'Tokaji', 'Shiraz', 'Vidal Blanc',
#        'Pinot Noir', 'Corvina, Rondinella, Molinara', 'Zinfandel',
#        'Merlot', 'Syrah', 'Bordeaux-style Red Blend',
#        'RhÃƒÂ´ne-style Red Blend', 'Tempranillo', 'Chenin Blanc',
#        'Pinot Blanc', 'Alvarinho', 'Pinotage',
#        'Bordeaux-style White Blend', 'Cabernet Franc', 'Sauvignon Blanc',
#        'Semillon-Chardonnay', 'RhÃƒÂ´ne-style White Blend',
#        'Petite Sirah', 'Melon', 'Tocai', 'Malbec', 'Sauvignon MusquÃƒÂ©',
#        'MourvÃƒÂ¨dre', 'Pinot Grigio', 'Tinto del Pais', 'Cortese',
#        'Petit Verdot', 'Semillon-Sauvignon Blanc', 'Pinot Meunier',
#        'Cabernet Sauvignon-Merlot', 'Viura', 'Pinot Gris', 'CastelÃƒÂ£o',
#        'Carignano', 'Traminer', 'CarmenÃƒÂ¨re', 'AlbariÃƒÂ±o',
#        'Cabernet Blend', 'Grenache', 'Nebbiolo', 'Baco Noir', 'Viognier',
#        'Portuguese Red', 'Roussanne', 'GewÃƒÂ¼rztraminer', 'Negroamaro',
#        'Xinomavro', 'Trajadura', 'Aglianico', 'Muscat Canelli',
#        'Pinot Nero', 'Prugnolo Gentile', 'Garnacha', 'Montepulciano',
#        'Muscat', 'Cabernet Sauvignon-Syrah', 'Cabernet Merlot',
#        'Garganega', 'Nosiola', 'Pinot Bianco', 'Johannisberg Riesling',
#        'Bual', 'Tannat', 'Furmint', 'Sangiovese Grosso', 'Raboso',
#        'BlaufrÃƒÂ¤nkisch', 'Tempranillo-Merlot', 'Picolit',
#        'Syrah-Cabernet', 'Mavroudi', 'Kekfrankos', 'Trebbiano',
#        'Nero di Troia', 'Touriga Nacional', 'Uva di Troia', 'Dolcetto',
#        'Touriga Franca', 'Sagrantino', 'GewÃƒÂ¼rztraminer-Riesling',
#        'Grechetto', 'Tinta de Toro', 'Primitivo', 'MencÃƒÂ\xada',
#        'Sauvignon Blanc-Semillon', 'Verdicchio', 'Barbera', 'Meritage',
#        'GrÃƒÂ¼ner Veltliner', 'Pedro XimÃƒÂ©nez', 'Corvina',
#        "Nero d'Avola", 'Petite Verdot', 'Savagnin', 'AragonÃƒÂƒÃ‚Âªs',
#        'Carignan', 'Shiraz-Viognier', 'Tocai Friulano', 'Ribolla Gialla',
#        'Moscato', 'Merlot-Cabernet Sauvignon', 'Trincadeira',
#        'Alicante Bouschet', 'Malvasia Fina',
#        'Cabernet Sauvignon-Cabernet Franc', 'Malbec-Cabernet Sauvignon',
#        'Sauvignon', 'Fiano', 'Portuguese White', 'Zweigelt',
#        'Chardonnay Weissburgunder', 'Gros and Petit Manseng',
#        'Chardonnay-Pinot Blanc', 'Tannat-Merlot', 'Gamay', 'Agiorgitiko',
#        'Coda di Volpe', 'Grenache-Syrah', 'Refosco', 'Lemberger',
#        'Tempranillo-Cabernet Sauvignon', 'Carricante',
#        'Nerello Mascalese', 'Counoise', 'Malbec-Tempranillo', 'Zlahtina',
#        'FernÃƒÂ£o Pires', 'Greco', 'Alfrocheiro', 'Grenache Blanc',
#        'RosÃƒÂ©', 'Vitovska', 'FumÃƒÂ© Blanc', 'Tinto Fino',
#        'Austrian Red Blend', 'St. Laurent', 'Gamay Noir', 'Mantonico',
#        'Prosecco', 'Graciano', 'Bonarda', 'Albana', 'G-S-M', 'Verdelho',
#        'Muskat Ottonel', 'Cabernet', 'Prieto Picudo', 'Verdejo',
#        'Plavac Mali', 'Roter Veltliner', 'Frappato', 'Tinta Roriz',
#        'Gaglioppo', 'Manzoni', 'Passerina', 'Claret',
#        'Cabernet Sauvignon-CarmenÃƒÂ¨re', 'Syrah-Viognier',
#        'Roter Traminer', 'Cabernet Sauvignon-Shiraz', 'RuchÃƒÂ©',
#        'Falanghina', 'Monastrell', 'Silvaner', 'Syrah-Grenache',
#        'Charbono', 'Malbec-Merlot', 'AligotÃƒÂ©', 'Moscato di Noto',
#        'Chambourcin', 'Viura-Verdejo', 'Rieslaner', 'TorrontÃƒÂ©s',
#        'Vermentino', 'Grenache-Shiraz', 'Cabernet Sauvignon-Malbec',
#        'Shiraz-Cabernet Sauvignon', 'Tempranillo-Garnacha', 'Malvasia',
#        'Portuguese Sparkling', 'Marsanne', "Loin de l'Oeil", 'Teroldego',
#        'Symphony', 'Chancellor', 'Sangiovese-Syrah', 'SÃƒÂ©millon',
#        'Saperavi', 'Bical', 'Friulano', 'Muscat of Alexandria',
#        'Cabernet Sauvignon-Sangiovese', 'Piedirosso', 'Okuzgozu',
#        'Norton', 'Sauvignon Gris', 'Petit Manseng', 'Pinot Auxerrois',
#        'Blauburger', 'Chenin Blanc-Chardonnay', 'Mazuelo', 'Marzemino',
#        'Touriga Nacional Blend', 'Assyrtico', 'Weissburgunder',
#        'Tinta Fina', 'Arneis', 'Macabeo', 'Ciliegiolo',
#        'Austrian white blend', 'Loureiro', 'SpÃƒÂ¤tburgunder',
#        'Verdejo-Viura', 'Colombard', 'Pugnitello', 'Malvasia Istriana',
#        'Marsanne-Roussanne', 'Moscadello', 'Syrah-Cabernet Franc',
#        'Gouveio', 'Touriga Nacional-Cabernet Sauvignon',
#        'Tempranillo-Shiraz', 'Baga', 'Pecorino', 'Lagrein',
#        'Malbec-Syrah', 'Godello', 'Cerceal', 'Moscato Giallo',
#        'Cabernet-Syrah', 'Cabernet Sauvignon-Merlot-Shiraz',
#        'Tannat-Cabernet', 'Viognier-Chardonnay', 'Viognier-Marsanne',
#        'Grignolino', 'Malvasia Bianca', 'Vignoles', 'Malagousia',
#        'Grillo', 'BabiÃƒÂ„Ã¢Â€Â¡', 'Cabernet Franc-Merlot',
#        "Cesanese d'Affile", 'Garnacha Blanca', 'Turbiana',
#        'Feteasca Neagra', 'MÃƒÂ¼ller-Thurgau', 'Carignane', 'Bovale',
#        'Zierfandler', 'Merlot-Malbec', 'AntÃƒÂ£o Vaz',
#        'Merlot-Cabernet Franc', 'Auxerrois', 'Inzolia',
#        'Provence red blend', 'Chardonnay-Viognier',
#        'Lambrusco di Sorbara', 'Arinto', 'Tinta Barroca', 'Picpoul',
#        'Cannonau', 'Marsanne-Viognier', 'Chardonel', 'Zibibbo',
#        'Barbera-Nebbiolo', 'Catarratto', 'Aleatico',
#        'Syrah-Cabernet Sauvignon', 'Dafni', 'Sylvaner',
#        'Carignan-Grenache', 'Glera', 'Durella', 'Posip', 'Maturana',
#        'Syrah-MourvÃƒÂ¨dre', 'SÃƒÂ¤mling', 'Garnacha-Monastrell',
#        'Malvasia Nera', 'Merlot-Cabernet', 'Grenache-MourvÃƒÂ¨dre',
#        'Cinsault', 'Monastrell-Syrah', 'Chinuri', 'Negrette',
#        'Verduzzo Friulano', 'Roussanne-Viognier',
#        'Cabernet Sauvignon-Tempranillo', 'Pansa Blanca', 'White Riesling',
#        'Alsace white blend', 'Sauvignon Blanc-Chenin Blanc',
#        'Chenin Blanc-Sauvignon Blanc', 'Sauvignon Blanc-Chardonnay',
#        'Sangiovese Cabernet', 'Welschriesling',
#        'Cabernet Sauvignon Grenache', 'Pallagrello Nero', 'Rotgipfler',
#        'Hondarrabi Zuri', 'Dornfelder', 'Casavecchia', 'Vranec', 'Rebula',
#        'Orange Muscat', 'Brachetto', 'Verdejo-Sauvignon Blanc',
#        'Tempranillo Blanco', 'Moscatel Roxo', 'Macabeo-Chardonnay',
#        'Pallagrello', 'Rosato', 'Garnacha-Syrah', 'Vidal',
#        'Malvasia-Viura', 'FeteascÃƒÂ‡Ã…Â½ RegalÃƒÂ‡Ã…Â½', 'Gros Manseng',
#        'Verdeca', 'Grenache-Carignan', 'Portuguese RosÃƒÂ©',
#        'Malbec-Cabernet Franc', 'Insolia', 'Kalecik Karasi',
#        'Chenin Blanc-Viognier', 'Tinta Francisca', 'Siria', 'Magliocco',
#        'Trousseau', 'Muscatel', 'Gelber Muskateller', 'Lambrusco',
#        'Mondeuse', 'Rosado', 'Syrah-Petite Sirah', 'Asprinio',
#        'Tannat-Syrah', 'Pinot Gris-GewÃƒÂ¼rztraminer',
#        'Chardonnay-Sauvignon', 'Xarel-lo', 'Garnacha-Tempranillo',
#        'Chasselas', 'Neuburger', 'Braucol', 'Pinot Noir-Gamay',
#        'JacquÃƒÂ¨re', 'Garnacha Tintorera', 'CarmenÃƒÂ¨re-Syrah',
#        'Rkatsiteli', 'Chardonnay-Semillon', 'Encruzado',
#        'Provence white blend', 'Colombard-Sauvignon Blanc', 'Altesse',
#        'Muscat Blanc', 'Moscatel GraÃƒÂºdo', 'Viura-Chardonnay',
#        'CarineÃƒÂ±a', 'Shiraz-Grenache', 'Bobal',
#        'Zierfandler-Rotgipfler', 'Schiava', 'Perricone', 'Mission',
#        'Tinta Madeira', 'Emir', 'Blanc du Bois', 'Assyrtiko', 'Kerner',
#        'Mavrud', 'Mandilaria', 'Lambrusco Grasparossa', 'Grenache Blend',
#        'Scheurebe', 'Pinot Noir-Syrah', 'Grauburgunder', 'Malbec Blend',
#        'Treixadura', 'Romorantin', 'Seyval Blanc', 'Muscadelle',
#        'Pignoletto', 'Muskat', 'Syrah-Carignan', 'Feteasca', 'Viosinho',
#        'Edelzwicker', 'Ondenc', 'Portuguiser', 'Moschofilero', 'Bastardo',
#        'Sacy', 'Alvarinho-Chardonnay', "Muscat d'Alexandrie",
#        'Shiraz-Tempranillo', 'Kisi', 'Colombard-Ugni Blanc',
#        'Shiraz-Cabernet', 'Grenache Gris', 'ÃƒÂ…Ã‚Â½ilavka',
#        'Tinta del Pais', 'Trousseau Gris', 'Nascetta', 'Carignan-Syrah',
#        'BoÃƒÂ„Ã…Â¸azkere', 'Rufete', 'Viognier-GewÃƒÂ¼rztraminer',
#        'Elbling', 'Viognier-Grenache Blanc', 'Chardonnay-Sauvignon Blanc',
#        'Jampal', 'Tinta MiÃƒÂºda', 'Alicante', 'Ugni Blanc-Colombard',
#        'Sirica', 'Robola', 'Gamza', 'Sciaccerellu',
#        'Cabernet Franc-Cabernet Sauvignon', 'ListÃƒÂ¡n Negro',
#        'CÃƒÂ³dega do Larinho', 'Narince', 'Fer Servadou',
#        'Tannat-Cabernet Franc', 'Centesimino', 'Tsolikouri',
#        'Loureiro-Arinto', 'Roussanne-Marsanne', 'Diamond',
#        'Malagouzia-Chardonnay', 'Pinot-Chardonnay', 'Grenache Noir',
#        'Maria Gomes-Bical', 'Marselan', 'Sherry'], dtype=object)

# %%
count = wine_data_pd["Variety"].value_counts()
count.head(50)
# Out:
# Pinot Noir                       2648
# Chardonnay                       2294
# Cabernet Sauvignon               1845
# Red Blend                        1726
# Bordeaux-style Red Blend         1376
# Sauvignon Blanc                  1025
# Riesling                         1022
# Syrah                             829
# RosÃƒÂ©                           735
# Merlot                            593
# Malbec                            549
# Nebbiolo                          537
# Sangiovese                        524
# Zinfandel                         517
# Portuguese Red                    492
# White Blend                       465
# Tempranillo                       355
# RhÃƒÂ´ne-style Red Blend          294
# Pinot Gris                        287
# Cabernet Franc                    262
# GrÃƒÂ¼ner Veltliner               252
# Portuguese White                  248
# Viognier                          203
# GewÃƒÂ¼rztraminer                 203
# Gamay                             191
# Bordeaux-style White Blend        189
# Pinot Grigio                      188
# Sparkling Blend                   176
# Petite Sirah                      170
# Sangiovese Grosso                 165
# Shiraz                            165
# Barbera                           152
# Corvina, Rondinella, Molinara     130
# Grenache                          125
# Chenin Blanc                      119
# Tempranillo Blend                 114
# CarmenÃƒÂ¨re                      112
# Champagne Blend                    97
# AlbariÃƒÂ±o                        93
# Port                               86
# RhÃƒÂ´ne-style White Blend         85
# Pinot Blanc                        82
# Aglianico                          72
# Garganega                          70
# Moscato                            68
# Nero d'Avola                       68
# Glera                              66
# Garnacha                           64
# Petit Verdot                       56
# Sauvignon                          54
# Name: Variety, dtype: int64

# %%
pinot_noir_df = wine_data_pd.loc[wine_data_pd["Variety"] == "Pinot Noir", :]
# Out:
#      Unnamed: 0                                              Title Country  \
# 54           54  Lafond 1997 Lafond Vineyard Pinot Noir (Santa ...      US
# 115         115  Castello di Borghese 1998 Hargrave Vineyard Pi...      US
# 116         116  La Bete 1998 Knight's Gambit Vyd Pinot Noir (W...      US
# 120         120  Brophy Clark 1998 Pinot Noir (Santa Maria Valley)      US
# 124         124  Cristom 1998 Marjorie Vineyards Pinot Noir (Wi...      US
# 138         138  Panther Creek 1998 Bednarik Vineyard Pinot Noi...      US
# 143         143   Silvan Ridge 1998 Pinot Noir (Willamette Valley)      US
# 147         147  Panther Creek 1998 Shea Vineyard Pinot Noir (A...      US
# 153         153  Brophy Clark 1998 Pinot Noir (Arroyo Grande Va...      US
# 154         154      Duck Pond 1998 Pinot Noir (Willamette Valley)      US
#
#      Points    Price    Province     Variety                Winery
# 54       82  $35.00   California  Pinot Noir                Lafond
# 115      84  $35.00     New York  Pinot Noir  Castello di Borghese
# 116      92  $40.00       Oregon  Pinot Noir               La Bete
# 120      85  $20.00   California  Pinot Noir          Brophy Clark
# 124      92  $39.00       Oregon  Pinot Noir               Cristom
# 138      92  $48.00       Oregon  Pinot Noir         Panther Creek
# 143      87  $22.00       Oregon  Pinot Noir          Silvan Ridge
# 147      94  $48.00      America  Pinot Noir         Panther Creek
# 153      89  $18.00   California  Pinot Noir          Brophy Clark
# 154      83   $9.00       Oregon  Pinot Noir             Duck Pond

# %%
pinot_noir_df = pinot_noir_df.sort_values("Points", ascending=False)
pinot_noir_topten = pinot_noir_df.head(10)
pinot_noir_topten
# Out:
#        Unnamed: 0                                              Title Country  \
# 9981         9981  Williams Selyem 2010 Hirsch Vineyard Pinot Noi...      US
# 1731         1731                     Clos de Tart 2005 Clos de Tart  France
# 16987       16987  Williams Selyem 2013 Westside Road Neighbors P...      US
# 1229         1229                  Louis Jadot 2005 Clos de la Roche  France
# 10072       10072  Williams Selyem 2010 Precious Mountain Vineyar...      US
# 4094         4094  Goldeneye 2007 Ten Degrees Pinot Noir (Anderso...      US
# 3609         3609  Joseph Swan Vineyards 2007 Trenton Estate Vine...      US
# 9499         9499  Williams Selyem 2010 30th Anniversary CuvÃƒÂ©e...      US
# 3459         3459  Goldeneye 2007 Confluence Vineyard Pinot Noir ...      US
# 19459       19459                  Louis Jadot 2014 Clos de la Roche  France
#
#        Points     Price    Province     Variety                 Winery
# 9981       99   $75.00   California  Pinot Noir        Williams Selyem
# 1731       98  $319.00     Burgundy  Pinot Noir           Clos de Tart
# 16987      98   $69.00   California  Pinot Noir        Williams Selyem
# 1229       98  $138.00     Burgundy  Pinot Noir            Louis Jadot
# 10072      98   $94.00   California  Pinot Noir        Williams Selyem
# 4094       98  $100.00   California  Pinot Noir              Goldeneye
# 3609       97   $52.00   California  Pinot Noir  Joseph Swan Vineyards
# 9499       97  $125.00   California  Pinot Noir        Williams Selyem
# 3459       97   $75.00   California  Pinot Noir              Goldeneye
# 19459      97  $286.00     Burgundy  Pinot Noir            Louis Jadot

# %%
chardonnay_df = wine_data_pd.loc[wine_data_pd["Variety"] == "Chardonnay", :]
chardonnay_df = chardonnay_df.sort_values("Points", ascending=False)
chardonnay_topten = chardonnay_df.head(10)
chardonnay_topten
# Out:
#        Unnamed: 0                                              Title Country  \
# 19313       19313              Louis Jadot 2014 BÃƒÂ¢tard-Montrachet  France
# 22035       22035  Wayfarer 2014 Wayfarer Vineyard Chardonnay (Fo...      US
# 16215       16215  Louis Jadot 2013 Les Demoiselles (Chevalier-Mo...  France
# 17511       17511  Domaine Jean-Paul et BenoÃƒÂ®t Droin 2013 Les ...  France
# 2522         2522         Domaine Leflaive 2006 BÃƒÂ¢tard-Montrachet  France
# 19182       19182                Louis Jadot 2014 Corton-Charlemagne  France
# 5469         5469  Domaine Leflaive 2008 Bienvenues BÃƒÂ¢tard-Mon...  France
# 13626       13626     Ramey 2012 Hyde Vineyard Chardonnay (Carneros)      US
# 4180         4180  Domaine Leflaive 2007 Les Pucelles Premier Cru...  France
# 17025       17025              Louis Jadot 2013 BÃƒÂ¢tard-Montrachet  France
#
#        Points     Price    Province     Variety  \
# 19313      98  $367.00     Burgundy  Chardonnay
# 22035      98   $80.00   California  Chardonnay
# 16215      97  $476.00     Burgundy  Chardonnay
# 17511      97   $69.00     Burgundy  Chardonnay
# 2522       97  $451.00     Burgundy  Chardonnay
# 19182      97  $184.00     Burgundy  Chardonnay
# 5469       97  $410.00     Burgundy  Chardonnay
# 13626      96   $65.00   California  Chardonnay
# 4180       96  $260.00     Burgundy  Chardonnay
# 17025      96  $370.00     Burgundy  Chardonnay
#
#                                      Winery
# 19313                           Louis Jadot
# 22035                              Wayfarer
# 16215                           Louis Jadot
# 17511  Domaine Jean-Paul et BenoÃƒÂ®t Droin
# 2522                       Domaine Leflaive
# 19182                           Louis Jadot
# 5469                       Domaine Leflaive
# 13626                                 Ramey
# 4180                       Domaine Leflaive
# 17025                           Louis Jadot

# %%
cab_sauv_df=wine_data_pd.loc[wine_data_pd["Variety"] == "Cabernet Sauvignon", :]
cab_sauv_df = cab_sauv_df.sort_values("Points", ascending=False)
cab_sauv_topten = cab_sauv_df.head(10)
cab_sauv_topten
# Out:
#        Unnamed: 0                                              Title Country  \
# 2431         2431    Cardinale 2006 Cabernet Sauvignon (Napa Valley)      US
# 5836         5836  Venge 2008 Family Reserve Cabernet Sauvignon (...      US
# 15707       15707  Alpha Omega 2012 Stagecoach Vineyard Cabernet ...      US
# 2248         2248  Quilceda Creek 2006 Cabernet Sauvignon (Columb...      US
# 7219         7219  Von Strasser 2009 Estate Vineyard Cabernet Sau...      US
# 3498         3498  Stonestreet 2007 Black Cougar Ridge Cabernet S...      US
# 6166         6166  Yao Ming 2009 Family Reserve Cabernet Sauvigno...      US
# 14544       14544  Alpha Omega 2012 Beckstoffer Georges III Caber...      US
# 6852         6852      Gandona 2009 Cabernet Sauvignon (Napa Valley)      US
# 2260         2260       Hestan 2006 Cabernet Sauvignon (Napa Valley)      US
#
#        Points     Price    Province             Variety          Winery
# 2431      100  $200.00   California  Cabernet Sauvignon       Cardinale
# 5836       99  $125.00   California  Cabernet Sauvignon           Venge
# 15707      99  $250.00   California  Cabernet Sauvignon     Alpha Omega
# 2248       98  $125.00   Washington  Cabernet Sauvignon  Quilceda Creek
# 7219       98   $70.00   California  Cabernet Sauvignon    Von Strasser
# 3498       97   $75.00   California  Cabernet Sauvignon     Stonestreet
# 6166       97  $625.00   California  Cabernet Sauvignon        Yao Ming
# 14544      97  $250.00   California  Cabernet Sauvignon     Alpha Omega
# 6852       97  $190.00   California  Cabernet Sauvignon         Gandona
# 2260       97  $100.00   California  Cabernet Sauvignon          Hestan

# %%
red_blend_df=wine_data_pd.loc[wine_data_pd["Variety"] == "Red Blend", :]
red_blend_df=red_blend_df.sort_values("Points", ascending=False)
red_blend_topten = red_blend_df.head(10)
red_blend_topten
# Out:
#        Unnamed: 0                                              Title Country  \
# 4744         4744  Marchesi Antinori 2008 Guado al Tasso (Bolgher...   Italy
# 9297         9297  Tenuta San Guido 2010 Sassicaia (Bolgheri Sass...   Italy
# 880           880  Tenuta San Guido 2004 Sassicaia (Bolgheri Sass...   Italy
# 22528       22528    ONX 2015 Reckoning Red (Templeton Gap District)      US
# 1909         1909        La Rioja Alta 2005 Gran Reserva 904 (Rioja)   Spain
# 3924         3924  Andrew Will 2007 Sorella Red Wine Red (Red Mou...      US
# 1287         1287  Betz Family 2005 Le Parrain Red Wine Red (Colu...      US
# 1026         1026        La Rioja Alta 2004 Gran Reserva 890 (Rioja)   Spain
# 5341         5341                      Monteverro 2008 Red (Toscana)   Italy
# 22039       22039    Biondi 2014 Contrada Monte San NicolÃƒÂ² (Etna)   Italy
#
#        Points     Price           Province    Variety             Winery
# 4744       98  $102.00             Tuscany  Red Blend  Marchesi Antinori
# 9297       97  $227.00             Tuscany  Red Blend   Tenuta San Guido
# 880        97  $190.00             Tuscany  Red Blend   Tenuta San Guido
# 22528      96   $58.00          California  Red Blend                ONX
# 1909       96   $50.00      Northern Spain  Red Blend      La Rioja Alta
# 3924       96   $64.00          Washington  Red Blend        Andrew Will
# 1287       96   $85.00          Washington  Red Blend        Betz Family
# 1026       96  $125.00      Northern Spain  Red Blend      La Rioja Alta
# 5341       95  $175.00             Tuscany  Red Blend         Monteverro
# 22039      95   $30.00   Sicily & Sardinia  Red Blend             Biondi

# %%
bord_red_df=wine_data_pd.loc[wine_data_pd["Variety"] == "Bordeaux-style Red Blend", :]
bord_red_df=bord_red_df.sort_values("Points", ascending=False)
bord_red_topten=bord_red_df.head(10)
bord_red_topten
# Out:
#        Unnamed: 0                                              Title Country  \
# 10344       10344        Chateau  Cheval Blanc 2010 Saint-ÃƒÂ‰milion  France
# 7265         7265  Chateau  Pontet-Canet 2009 Barrel sample (Paui...  France
# 5090         5090  Pirouette 2008 Red Wine Red (Columbia Valley (...      US
# 10962       10962                      Chateau  Latour 2011 Pauillac  France
# 3821         3821                   Continuum 2007 Red (Napa Valley)      US
# 7657         7657                        Ovid 2009 Red (Napa Valley)      US
# 9081         9081        Vieux Chateau  Certan 2010 Saint-ÃƒÂ‰milion  France
# 19751       19751              Chateau  Figeac 2014 Saint-ÃƒÂ‰milion  France
# 4973         4973        VeritÃƒÂ© 2008 Le Desir Red (Sonoma County)      US
# 20542       20542              Chateau  Ausone 2014 Saint-ÃƒÂ‰milion  France
#
#        Points       Price    Province                   Variety  \
# 10344     100  $1,500.00     Bordeaux  Bordeaux-style Red Blend
# 7265       99         NaN    Bordeaux  Bordeaux-style Red Blend
# 5090       98     $50.00   Washington  Bordeaux-style Red Blend
# 10962      97    $660.00     Bordeaux  Bordeaux-style Red Blend
# 3821       97    $140.00   California  Bordeaux-style Red Blend
# 7657       97    $195.00   California  Bordeaux-style Red Blend
# 9081       97         NaN    Bordeaux  Bordeaux-style Red Blend
# 19751      97     $90.00     Bordeaux  Bordeaux-style Red Blend
# 4973       97    $450.00   California  Bordeaux-style Red Blend
# 20542      97    $530.00     Bordeaux  Bordeaux-style Red Blend
#
#                       Winery
# 10344  Chateau  Cheval Blanc
# 7265   Chateau  Pontet-Canet
# 5090               Pirouette
# 10962        Chateau  Latour
# 3821               Continuum
# 7657                    Ovid
# 9081   Vieux Chateau  Certan
# 19751        Chateau  Figeac
# 4973               VeritÃƒÂ©
# 20542        Chateau  Ausone

# %%
sauv_blanc_df=wine_data_pd.loc[wine_data_pd["Variety"] == "Sauvignon Blanc", :]
sauv_blanc_df=sauv_blanc_df.sort_values("Points", ascending=False)
sauv_blanc_topten=sauv_blanc_df.head(10)
sauv_blanc_topten
# Out:
#        Unnamed: 0                                              Title  Country  \
# 21242       21242  Domaine Vacheron 2014 L'Enclos des Remparts Sa...   France
# 5400         5400  Chalk Hill 2008 Musque Sauvignon Blanc (Chalk ...       US
# 15763       15763              Henri Bourgeois 2012 Jadis (Sancerre)   France
# 23342       23342            Daniel Chotard 2015 Les Cris (Sancerre)   France
# 24081       24081  Galerie 2015 Equitem Sauvignon Blanc (Knights ...       US
# 21579       21579      Henri Bourgeois 2014 Etienne Henri (Sancerre)   France
# 5412         5412  Henri Bourgeois 2008 Le M.D. de Bourgeois (San...   France
# 16442       16442  Neumeister 2013 Moarfeitl Sauvignon Blanc (SÃƒ...  Austria
# 21096       21096              Michel Vattan 2014 Les L-O (Sancerre)   France
# 23124       23124            Daniel Chotard 2015 Les Cris (Sancerre)   France
#
#        Points    Price             Province          Variety            Winery
# 21242      96      NaN         France Other  Sauvignon Blanc  Domaine Vacheron
# 5400       95  $40.00            California  Sauvignon Blanc        Chalk Hill
# 15763      95  $55.00          Loire Valley  Sauvignon Blanc   Henri Bourgeois
# 23342      94  $39.00          Loire Valley  Sauvignon Blanc    Daniel Chotard
# 24081      94  $30.00            California  Sauvignon Blanc           Galerie
# 21579      94  $65.00          Loire Valley  Sauvignon Blanc   Henri Bourgeois
# 5412       94  $36.00          Loire Valley  Sauvignon Blanc   Henri Bourgeois
# 16442      94  $60.00   SÃƒÂ¼doststeiermark  Sauvignon Blanc        Neumeister
# 21096      94  $35.00          Loire Valley  Sauvignon Blanc     Michel Vattan
# 23124      94  $39.00          Loire Valley  Sauvignon Blanc    Daniel Chotard

# %%
riesling=wine_data_pd.loc[wine_data_pd["Variety"] == "Riesling", :]
riesling=riesling.sort_values("Points", ascending=False)
riesling_topten=riesling.head(10)
riesling_topten
# Out:
#        Unnamed: 0                                              Title  Country  \
# 22902       22902  Robert Weil 2015 Kiedrich GrÃƒÂ¤fenberg Trocke...  Germany
# 19749       19749  Trimbach 2014 Schlossberg Grand Cru Riesling (...   France
# 23962       23962  Domaine Ostertag 2015 Muenchberg Grand Cru Rie...   France
# 16574       16574  BrÃƒÂ¼ndlmayer 2013 Heiligenstein Reserve Lyra...  Austria
# 7427         7427  Domdechant Werner 2009 Hochheimer Domdechaney ...  Germany
# 4126         4126      Trimbach 2007 Clos Ste Hune Riesling (Alsace)   France
# 9682         9682  Robert Weil 2010 Kiedrich GrÃƒÂ¤fenberg Trocke...  Germany
# 10500       10500  ThÃƒÂ¶rle 2011 Saulheimer HÃƒÂ¶lle Trockenbeer...  Germany
# 12910       12910  Domaine Weinbach 2011 Schlossberg Grand Cru Ri...   France
# 6180         6180  Maximin GrÃƒÂ¼nhÃƒÂ¤user 2009 Herrenberg Eiswe...  Germany
#
#        Points     Price     Province   Variety                    Winery
# 22902      98  $775.00      Rheingau  Riesling               Robert Weil
# 19749      97  $100.00        Alsace  Riesling                  Trimbach
# 23962      97   $66.00        Alsace  Riesling          Domaine Ostertag
# 16574      96   $35.00       Kamptal  Riesling            BrÃƒÂ¼ndlmayer
# 7427       96  $271.00      Rheingau  Riesling         Domdechant Werner
# 4126       96       NaN       Alsace  Riesling                  Trimbach
# 9682       96  $672.00      Rheingau  Riesling               Robert Weil
# 10500      96  $150.00   Rheinhessen  Riesling                 ThÃƒÂ¶rle
# 12910      96   $37.00        Alsace  Riesling          Domaine Weinbach
# 6180       96  $228.00         Mosel  Riesling  Maximin GrÃƒÂ¼nhÃƒÂ¤user

# %%
syrah=wine_data_pd.loc[wine_data_pd["Variety"] == "Syrah", :]
syrah=syrah.sort_values("Points", ascending=False)
syrah_topten=syrah.head(10)
syrah_topten
# Out:
#        Unnamed: 0                                              Title  \
# 6379         6379  Cayuse 2009 En Chamberlin Vineyard Syrah (Wall...
# 8812         8812   Charles Smith 2010 Royal City Syrah (Washington)
# 9792         9792  Cayuse 2010 Armada Vineyard Syrah (Walla Walla...
# 4625         4625  Donelan 2008 Richards Family Vineyard Syrah (S...
# 21175       21175   Stolo 2014 Estate Syrah (San Luis Obispo County)
# 13726       13726  Horsepower 2012 The Tribe Vineyard Syrah (Wall...
# 16527       16527       Trinity Hill 2013 Homage Syrah (Hawke's Bay)
# 1325         1325            Novy 2005 Syrah (Santa Lucia Highlands)
# 8541         8541  Les Vins de Vienne 2010 Les Chirats de Saint-C...
# 18805       18805  K Vintners 2013 The Hidden Northridge Vineyard...
#
#            Country  Points     Price         Province Variety  \
# 6379            US      99   $75.00            Oregon   Syrah
# 8812            US      97  $140.00        Washington   Syrah
# 9792            US      97   $90.00        Washington   Syrah
# 4625            US      97   $90.00        California   Syrah
# 21175           US      96   $40.00        California   Syrah
# 13726           US      96  $115.00        Washington   Syrah
# 16527  New Zealand      95  $100.00       Hawke's Bay   Syrah
# 1325            US      95   $27.00        California   Syrah
# 8541        France      95  $120.00   RhÃƒÂ´ne Valley   Syrah
# 18805           US      95   $70.00        Washington   Syrah
#
#                    Winery
# 6379               Cayuse
# 8812        Charles Smith
# 9792               Cayuse
# 4625              Donelan
# 21175               Stolo
# 13726          Horsepower
# 16527        Trinity Hill
# 1325                 Novy
# 8541   Les Vins de Vienne
# 18805          K Vintners

# %%
rose=wine_data_pd.loc[wine_data_pd["Variety"] == "RosÃƒÂ©", :]
rose=rose.sort_values("Points", ascending=False)
rose_topten=rose.head(10)
rose_topten
# Out:
#        Unnamed: 0                                              Title Country  \
# 5416         5416   Schramsberg 2008 J. Schram RosÃƒÂ© (North Coast)      US
# 24399       24399  Chateau  Vignelaure 2016 RosÃƒÂ© (Coteaux d'Ai...  France
# 20023       20023  Chateau  Coussin 2014 CuvÃƒÂ©e CÃƒÂ©sar ÃƒÂ  S...  France
# 22916       22916  Chateau  Saint-Maur 2015 Clos de Capelune RosÃ...  France
# 22497       22497  Chateau  Minuty 2015 Rose et Or RosÃƒÂ© (CÃƒÂ´...  France
# 11171       11171  Chateau  d'Esclans 2011 Garrus RosÃƒÂ© (CÃƒÂ´t...  France
# 23035       23035  Chateau  Grand Boise 2015 CuvÃƒÂ©e Jadis RosÃƒ...  France
# 24857       24857               Chateau  la GenestiÃƒÂ¨re 2016 Tavel  France
# 24244       24244  Domaine de la BÃƒÂ©gude 2015 L'IrrÃƒÂ©ductible...  France
# 11475       11475  Chateau  Vignelaure 2011 RosÃƒÂ© (Coteaux d'Ai...  France
#
#        Points     Price         Province  Variety                     Winery
# 5416       96  $150.00        California  RosÃƒÂ©                Schramsberg
# 24399      94   $20.00          Provence  RosÃƒÂ©        Chateau  Vignelaure
# 20023      93   $60.00          Provence  RosÃƒÂ©           Chateau  Coussin
# 22916      93   $65.00          Provence  RosÃƒÂ©        Chateau  Saint-Maur
# 22497      93   $40.00          Provence  RosÃƒÂ©            Chateau  Minuty
# 11171      93   $90.00          Provence  RosÃƒÂ©         Chateau  d'Esclans
# 23035      93   $30.00          Provence  RosÃƒÂ©       Chateau  Grand Boise
# 24857      92   $22.00   RhÃƒÂ´ne Valley  RosÃƒÂ©  Chateau  la GenestiÃƒÂ¨re
# 24244      92   $40.00          Provence  RosÃƒÂ©    Domaine de la BÃƒÂ©gude
# 11475      92   $21.00          Provence  RosÃƒÂ©        Chateau  Vignelaure

# %%
merlot=wine_data_pd.loc[wine_data_pd["Variety"] == "Merlot", :]
merlot=merlot.sort_values("Points", ascending=False)
merlot_topten=merlot.head(10)
merlot_topten
# Out:
#        Unnamed: 0                                              Title  Country  \
# 14036       14036  Feudi di San Gregorio 2012 Patrimo Merlot (Cam...    Italy
# 3292         3292  Woodward Canyon 2007 Merlot (Columbia Valley (...       US
# 1866         1866           Tua Rita 2005 Redigaffi Merlot (Toscana)    Italy
# 1179         1179    Duckhorn 2004 Estate Grown Merlot (Napa Valley)       US
# 8954         8954  Leonetti Cellar 2010 Merlot (Walla Walla Valle...       US
# 2562         2562    Northstar 2006 Merlot (Walla Walla Valley (WA))       US
# 1630         1630  Duckhorn 2005 Three Palms Vineyard Merlot (Nap...       US
# 13560       13560        Netzl 2012 BÃƒÂ¤rnreiser Merlot (Carnuntum)  Austria
# 19820       19820                  Duckhorn 2014 Merlot (Atlas Peak)       US
# 8356         8356  Market Vineyards 2010 Alpha Merlot (Red Mountain)       US
#
#        Points     Price        Province Variety                 Winery
# 14036      96  $105.00   Southern Italy  Merlot  Feudi di San Gregorio
# 3292       95   $39.00       Washington  Merlot        Woodward Canyon
# 1866       95  $275.00          Tuscany  Merlot               Tua Rita
# 1179       95   $85.00       California  Merlot               Duckhorn
# 8954       95   $70.00       Washington  Merlot        Leonetti Cellar
# 2562       94   $50.00       Washington  Merlot              Northstar
# 1630       94   $85.00       California  Merlot               Duckhorn
# 13560      94   $44.00        Carnuntum  Merlot                  Netzl
# 19820      93   $75.00       California  Merlot               Duckhorn
# 8356       93   $52.00       Washington  Merlot       Market Vineyards

# %%
malbec=wine_data_pd.loc[wine_data_pd["Variety"] == "Malbec", :]
malbec=malbec.sort_values("Points", ascending=False)
malbec_topten=malbec.head(10)
malbec_topten
# Out:
#        Unnamed: 0                                              Title  \
# 2086         2086  Bodega Catena Zapata 2006 Nicasia Vineyard Mal...
# 8576         8576              ColomÃƒÂ© 2010 Reserva Malbec (Salta)
# 12072       12072       Chateau  du CÃƒÂ¨dre 2011 GC Malbec (Cahors)
# 9756         9756  ViÃƒÂ±a Cobos 2010 Cobos Marchiori Vineyard Ma...
# 15243       15243  Alta Vista 2012 Single Vineyard Temis Malbec (...
# 18615       18615  Devil Proof 2013 Farrow Ranch Malbec (Alexande...
# 18056       18056  Alta Vista 2013 Single Vineyard Serenade Malbe...
# 17920       17920  Charles Smith 2013 Broncho Stoneridge Vineyard...
# 13621       13621  ViÃƒÂ±a Cobos 2012 Bramare Marchiori Vineyard ...
# 2089         2089  Jean-Luc BaldÃƒÂ¨s 2006 Clos Triguedina The Ne...
#
#          Country  Points     Price          Province Variety  \
# 2086   Argentina      97  $120.00   Mendoza Province  Malbec
# 8576   Argentina      95   $90.00              Other  Malbec
# 12072     France      95  $165.00   Southwest France  Malbec
# 9756   Argentina      95  $225.00   Mendoza Province  Malbec
# 15243  Argentina      95   $48.00   Mendoza Province  Malbec
# 18615         US      95  $125.00         California  Malbec
# 18056  Argentina      94   $48.00   Mendoza Province  Malbec
# 17920         US      94   $70.00         Washington  Malbec
# 13621  Argentina      94   $90.00   Mendoza Province  Malbec
# 2089      France      94       NaN  Southwest France  Malbec
#
#                      Winery
# 2086   Bodega Catena Zapata
# 8576              ColomÃƒÂ©
# 12072  Chateau  du CÃƒÂ¨dre
# 9756          ViÃƒÂ±a Cobos
# 15243            Alta Vista
# 18615           Devil Proof
# 18056            Alta Vista
# 17920         Charles Smith
# 13621         ViÃƒÂ±a Cobos
# 2089     Jean-Luc BaldÃƒÂ¨s

# %%
nebbiolo=wine_data_pd.loc[wine_data_pd["Variety"] == "Nebbiolo", :]
nebbiolo=nebbiolo.sort_values("Points", ascending=False)
nebbiolo_topten=nebbiolo.head(10)
nebbiolo_topten
# Out:
#        Unnamed: 0                                              Title Country  \
# 3497         3497  Gaja 2007 SorÃƒÂƒÃ‚Â¬ San Lorenzo Nebbiolo (La...   Italy
# 5875         5875  Mascarello Giuseppe e Figlio 2008 CÃƒÂ  d'Mori...   Italy
# 18123       18123                       Brezza 2013 Cannubi (Barolo)   Italy
# 16367       16367             Brovia 2013 GarblÃƒÂ¨t SuÃƒÂ¨ (Barolo)   Italy
# 18068       18068          Brovia 2013 Brea Vigna CÃƒÂ  Mia (Barolo)   Italy
# 10001       10001  Mascarello Giuseppe e Figlio 2010 Villero (Bar...   Italy
# 18410       18410                   Elvio Cogno 2013 Ravera (Barolo)   Italy
# 18030       18030             Giacomo Fenocchio 2013 Bussia (Barolo)   Italy
# 8432         8432           Rivetto 2010 Briccolina Riserva (Barolo)   Italy
# 4961         4961    Luigi Oddero & Figli 2008 Vigna Rionda (Barolo)   Italy
#
#        Points     Price  Province   Variety                        Winery
# 3497       99  $440.00   Piedmont  Nebbiolo                          Gaja
# 5875       99  $595.00   Piedmont  Nebbiolo  Mascarello Giuseppe e Figlio
# 18123      98   $60.00   Piedmont  Nebbiolo                        Brezza
# 16367      98   $83.00   Piedmont  Nebbiolo                        Brovia
# 18068      97   $96.00   Piedmont  Nebbiolo                        Brovia
# 10001      97  $100.00   Piedmont  Nebbiolo  Mascarello Giuseppe e Figlio
# 18410      97   $82.00   Piedmont  Nebbiolo                   Elvio Cogno
# 18030      97   $55.00   Piedmont  Nebbiolo             Giacomo Fenocchio
# 8432       96  $210.00   Piedmont  Nebbiolo                       Rivetto
# 4961       96  $131.00   Piedmont  Nebbiolo          Luigi Oddero & Figli

# %%
sangiovese=wine_data_pd.loc[wine_data_pd["Variety"] == "Sangiovese", :]
sangiovese=sangiovese.sort_values("Points", ascending=False)
sangiovese_topten=sangiovese.head(10)
sangiovese_topten
# Out:
#        Unnamed: 0                                              Title Country  \
# 2299         2299  Il Paradiso di Manfredi 2006 Riserva (Brunello...   Italy
# 9688         9688       Felsina 2010 Fontalloro Sangiovese (Toscana)   Italy
# 4694         4694  Michele Satta 2008 Cavaliere Sangiovese (Toscana)   Italy
# 14423       14423                Armilla 2012 Brunello di Montalcino   Italy
# 9419         9419  Ormanni 2010 Etichetta Storica Gran Selezione ...   Italy
# 2131         2131  Col d'Orcia 2006 Poggio al Vento Riserva (Brun...   Italy
# 12043       12043        Gianni Brunelli 2011 Brunello di Montalcino   Italy
# 8174         8174       Mocali 2010 Riserva (Brunello di Montalcino)   Italy
# 11627       11627              Cerbaiona 2011 Brunello di Montalcino   Italy
# 11972       11972  Livio Sassetti 2011 Pertimali (Brunello di Mon...   Italy
#
#        Points     Price Province     Variety                   Winery
# 2299       97  $152.00   Tuscany  Sangiovese  Il Paradiso di Manfredi
# 9688       95   $62.00   Tuscany  Sangiovese                  Felsina
# 4694       95   $75.00   Tuscany  Sangiovese            Michele Satta
# 14423      95   $63.00   Tuscany  Sangiovese                  Armilla
# 9419       95   $45.00   Tuscany  Sangiovese                  Ormanni
# 2131       95  $150.00   Tuscany  Sangiovese              Col d'Orcia
# 12043      95   $56.00   Tuscany  Sangiovese          Gianni Brunelli
# 8174       95   $85.00   Tuscany  Sangiovese                   Mocali
# 11627      95       NaN  Tuscany  Sangiovese                Cerbaiona
# 11972      94   $55.00   Tuscany  Sangiovese           Livio Sassetti

# %%
zinfandel=wine_data_pd.loc[wine_data_pd["Variety"] == "Zinfandel", :]
zinfandel=zinfandel.sort_values("Points", ascending=False)
zinfandel_topten=zinfandel.head(10)
zinfandel_topten
# Out:
#        Unnamed: 0                                              Title Country  \
# 7700         7700  Seghesio 2009 Old Vine Zinfandel (Dry Creek Va...      US
# 17427       17427  Pulchella 2013 Mercenary Reserve 25 Zinfandel ...      US
# 15250       15250  Williams Selyem 2012 Bacigalupi Vineyard Zinfa...      US
# 21559       21559  Robert Biale 2014 Aldo's Vineyard Estate Grown...      US
# 7868         7868  St. Francis 2009 Pagani Vineyard Zinfandel (So...      US
# 22734       22734  Robert Biale 2015 Black Chicken Zinfandel (Nap...      US
# 12097       12097  Newsome-Harlow 2011 The Donner Party The Dalto...      US
# 21937       21937  Three 2014 Bigelow Zinfandel (Contra Costa Cou...      US
# 21391       21391  Scott Harvey 2014 Vineyard 1869 Zinfandel (Ama...      US
# 1624         1624       Edizione Pennino 2005 Zinfandel (Rutherford)      US
#
#        Points    Price    Province    Variety            Winery
# 7700       94  $38.00   California  Zinfandel          Seghesio
# 17427      94  $50.00   California  Zinfandel         Pulchella
# 15250      94  $55.00   California  Zinfandel   Williams Selyem
# 21559      94  $78.00   California  Zinfandel      Robert Biale
# 7868       93  $45.00   California  Zinfandel       St. Francis
# 22734      93  $48.00   California  Zinfandel      Robert Biale
# 12097      93  $36.00   California  Zinfandel    Newsome-Harlow
# 21937      93  $34.00   California  Zinfandel             Three
# 21391      93  $48.00   California  Zinfandel      Scott Harvey
# 1624       93  $40.00   California  Zinfandel  Edizione Pennino

# %%
portuguesred=wine_data_pd.loc[wine_data_pd["Variety"] == "Portuguese Red", :]
portuguesred=portuguesred.sort_values("Points", ascending=False)
portuguesred_topten=portuguesred.head(10)
portuguesred_topten
# Out:
#        Unnamed: 0                                              Title  \
# 15098       15098                     MouchÃƒÂ£o 2012 Red (Alentejo)
# 19282       19282            Quinta do Vale MeÃƒÂ£o 2014 Red (Douro)
# 21240       21240                   Quinta do Noval 2014 Red (Douro)
# 13897       13897        Quinta dos MurÃƒÂ§as 2012 VV 47 Red (Douro)
# 3145         3145                   MouchÃƒÂ£o 2007 Red (Alentejano)
# 14530       14530  Quinta Vale Dona Maria 2012 Vinha do Rio Red (...
# 18618       18618  Quinta Vale Dona Maria 2013 VVV Valleys Red (D...
# 7004         7004      Wine & Soul 2009 Pintas Character Red (Douro)
# 23498       23498  JosÃƒÂ© Maria da Fonseca 2015 JosÃƒÂ© de Sousa...
# 5449         5449                Vinha Paz 2008 Reserva Red (DÃƒÂ£o)
#
#         Country  Points     Price    Province         Variety  \
# 15098  Portugal      97   $75.00     Alentejo  Portuguese Red
# 19282  Portugal      95  $100.00        Douro  Portuguese Red
# 21240  Portugal      95   $87.00        Douro  Portuguese Red
# 13897  Portugal      95  $100.00        Douro  Portuguese Red
# 3145   Portugal      95   $36.00   Alentejano  Portuguese Red
# 14530  Portugal      95  $150.00        Douro  Portuguese Red
# 18618  Portugal      95   $34.00        Douro  Portuguese Red
# 7004   Portugal      95   $40.00        Douro  Portuguese Red
# 23498  Portugal      94   $20.00   Alentejano  Portuguese Red
# 5449   Portugal      94   $35.00       DÃƒÂ£o  Portuguese Red
#
#                          Winery
# 15098                MouchÃƒÂ£o
# 19282    Quinta do Vale MeÃƒÂ£o
# 21240           Quinta do Noval
# 13897      Quinta dos MurÃƒÂ§as
# 3145                 MouchÃƒÂ£o
# 14530    Quinta Vale Dona Maria
# 18618    Quinta Vale Dona Maria
# 7004                Wine & Soul
# 23498  JosÃƒÂ© Maria da Fonseca
# 5449                  Vinha Paz

# %%
White Blend
